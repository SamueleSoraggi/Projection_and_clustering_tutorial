# %%
# Compute t-SNE probability score matrix. #
# Args:
# X: A numeric data matrix.
# perplexity: Desired perplexity score for all variables. #
# Returns:
# A matrix of probability densities.
casl_tsne_p <- function(X, perplexity=15, tol=1e-3)
    {
    D <- as.matrix(dist(X))^2
    P <- matrix(0, nrow(X), nrow(X)) 
    svals <- rep(1, nrow(X))
    for (i in seq_along(svals)) {
        srange <- c(0, 100)
        tries <- 0
        diff <- +Inf
        old_H <- 0
        while(diff>tol) {
            Pji <- exp(-D[i, -i] / (2 * svals[i])) 
            Pji <- Pji / sum(Pji)
            H <- -1 * Pji %*% log(Pji, 2)
            print(diff)
            if (H < log(perplexity, 2)){
                srange[1] <- svals[i]
                svals[i] <- (svals[i] + srange[2]) / 2
                }
            else {
                srange[2] <- svals[i]
                svals[i] <- (svals[i] + srange[1]) / 2
                } 
            diff <- abs(old_H-H)
            old_H <- H
            }
        P[i, -i] <- Pji
        }
    return(0.5 * (P + t(P)) / sum(P)) 
    }

# %%
# Compute t-SNE embeddings. #
# Args:
# X: A numeric data matrix.
# perplexity: Desired perplexity score for all variables.
# k: Dimensionality of the output.
# iter: Number of iterations to perform.
# rho: A positive numeric learning rate. #
# Returns:
# An nrow(X) by k matrix of t-SNE embeddings.

casl_tsne <- function(X, perplexity=30, k=2L, iter=1000L, rho=100) {
    
    Y <- matrix(rnorm(nrow(X) * k), ncol = k)
    P <- casl_tsne_p(X, perplexity) 
    del <- matrix(0, nrow(Y), ncol(Y))
    for (inum in seq_len(iter)) {
        num <- matrix(0, nrow(X), nrow(X))
        for (j in seq_len(nrow(X))) { 
            for (k in seq_len(nrow(X))) {
                num[j, k] = 1 / (1 + sum((Y[j,] - Y[k, ])^2)) 
            }
        }
    diag(num) <- 0
    Q <- num / sum(num)
    stiffnesses <- 4 * (P - Q) * num 
    for (i in seq_len(nrow(X))){
        del[i, ] <- stiffnesses[i, ] %*% t(Y[i, ] - t(Y))
    }
    Y <- Y - rho * del
    Y <- t(t(Y) - apply(Y, 2, mean)) 
    }
return(Y)  
}

# %%
t = read.table("Data/customer personality.csv", sep="\t", header=T)

# %%
summary(t)
# Out:
#        ID          Year_Birth    Education         Marital_Status
#  Min.   :    0   Min.   :1893   Length:2240        Length:2240
#  1st Qu.: 2828   1st Qu.:1959   Class :character   Class :character
#  Median : 5458   Median :1970   Mode  :character   Mode  :character
#  Mean   : 5592   Mean   :1969
#  3rd Qu.: 8428   3rd Qu.:1977
#  Max.   :11191   Max.   :1996
#
#      Income          Kidhome          Teenhome      Dt_Customer
#  Min.   :  1730   Min.   :0.0000   Min.   :0.0000   Length:2240
#  1st Qu.: 35303   1st Qu.:0.0000   1st Qu.:0.0000   Class :character
#  Median : 51382   Median :0.0000   Median :0.0000   Mode  :character
#  Mean   : 52247   Mean   :0.4442   Mean   :0.5062
#  3rd Qu.: 68522   3rd Qu.:1.0000   3rd Qu.:1.0000
#  Max.   :666666   Max.   :2.0000   Max.   :2.0000
#  NA's   :24
#     Recency         MntWines         MntFruits     MntMeatProducts
#  Min.   : 0.00   Min.   :   0.00   Min.   :  0.0   Min.   :   0.0
# ...

# %%
X = t[ ,c("Income",
         "Recency", "MntWines", "MntFruits", "MntMeatProducts",
         "MntFishProducts", "MntSweetProducts", "MntGoldProds", "NumDealsPurchases",
         "NumWebPurchases", "NumCatalogPurchases", "NumStorePurchases", "NumWebVisitsMonth") ]

# %%
head(X)
# Out:
#   Income Recency MntWines MntFruits MntMeatProducts MntFishProducts
# 1 58138  58      635      88        546             172
# 2 46344  38       11       1          6               2
# 3 71613  26      426      49        127             111
# 4 26646  26       11       4         20              10
# 5 58293  94      173      43        118              46
# 6 62513  16      520      42         98               0
#   MntSweetProducts MntGoldProds NumDealsPurchases NumWebPurchases
# 1 88               88           3                 8
# 2  1                6           2                 1
# 3 21               42           1                 8
# 4  3                5           2                 2
# 5 27               15           5                 5
# 6 42               14           2                 6
#   NumCatalogPurchases NumStorePurchases NumWebVisitsMonth
# 1 10                   4                7
# 2  1                   2                5
# ...

# %% [markdown]
# dropping 24 NaNs

# %%
X = X[rowSums(is.na(X))==0,]

# %%
X_std = apply(X, 2, function(x){(x-mean(x))/sd(x)})

# %%
head(X_std)
# Out:
#   Income     Recency    MntWines   MntFruits  MntMeatProducts MntFishProducts
# 1  0.2340099  0.3104621  0.9780050  1.5490798  1.6898454       2.4540138
# 2 -0.2345065 -0.3804236 -0.8718271 -0.6371840 -0.7178241      -0.6508910
# 3  0.7693040 -0.7949549  0.3584298  0.5690305 -0.1783278       1.3399009
# 4 -1.0170092 -0.7949549 -0.8718271 -0.5617956 -0.6554030      -0.5047778
# 5  0.2401673  1.5540562 -0.3915822  0.4182537 -0.2184556       0.1527314
# 6  0.4078067 -1.1403978  0.6370904  0.3931242 -0.3076286      -0.6874192
#   MntSweetProducts MntGoldProds NumDealsPurchases NumWebPurchases
# 1  1.4844919006     0.84983876   0.3516341         1.4282310
# 2 -0.6337371427    -0.73270190  -0.1681932        -1.1256271
# 3 -0.1467879374    -0.03792796  -0.6880206         1.4282310
# 4 -0.5850422222    -0.75200118  -0.1681932        -0.7607902
# 5 -0.0007031757    -0.55900842   1.3912888         0.3337204
# 6  0.3645087283    -0.57830769  -0.1681932         0.6985572
# ...

# %%
summary(X_std)
# Out:
#      Income            Recency              MntWines         MntFruits
#  Min.   :-2.00680   Min.   :-1.6931063   Min.   :-0.9044   Min.   :-0.6623
#  1st Qu.:-0.67311   1st Qu.:-0.8640435   1st Qu.:-0.8333   1st Qu.:-0.6121
#  Median :-0.03439   Median :-0.0004365   Median :-0.3871   Median :-0.4613
#  Mean   : 0.00000   Mean   : 0.0000000   Mean   : 0.0000   Mean   : 0.0000
#  3rd Qu.: 0.64651   3rd Qu.: 0.8631705   3rd Qu.: 0.5926   3rd Qu.: 0.1670
#  Max.   :24.40777   Max.   : 1.7267776   Max.   : 3.5215   Max.   : 4.3385
#  MntMeatProducts   MntFishProducts   MntSweetProducts   MntGoldProds
#  Min.   :-0.7446   Min.   :-0.6874   Min.   :-0.6581   Min.   :-0.8485
#  1st Qu.:-0.6732   1st Qu.:-0.6326   1st Qu.:-0.6337   1st Qu.:-0.6748
#  Median :-0.4414   Median :-0.4682   Median :-0.4633   Median :-0.3757
#  Mean   : 0.0000   Mean   : 0.0000   Mean   : 0.0000   Mean   : 0.0000
#  3rd Qu.: 0.2909   3rd Qu.: 0.2258   3rd Qu.: 0.1454   3rd Qu.: 0.2323
# ...

# %%
library(FactoMineR)

# %%
PCA = PCA(X_std, scale.unit = TRUE, ncp = 10)

# %%
plot(PCA$ind$coord[,1],PCA$ind$coord[,2])
# Out:
# plot without title

# %%
Y10 <- casl_tsne(PCA$ind$coord[1:200,])
# Out:
# [1] Inf
#          [,1]
# [1,] 4.196734
#          [,1]
# [1,] 3.423889
#            [,1]
# [1,] 0.04266402
#           [,1]
# [1,] 0.1398356
#           [,1]
# [1,] 0.3652878
#           [,1]
# [1,] 0.6067907
#           [,1]
# [1,] 0.6114415
#           [,1]
# [1,] 0.5118852
#           [,1]
# [1,] 0.4155202
#           [,1]
# [1,] 0.3032376
#           [,1]
# [1,] 0.1631334
#            [,1]
# [1,] 0.07256574
#            [,1]
# [1,] 0.03435829
#            [,1]
# [1,] 0.01673279
#             [,1]
# [1,] 0.008330168
#            [,1]
# [1,] 0.00417407
#             [,1]
# [1,] 0.002080287
#             [,1]
# [1,] 0.001039583
# [1] Inf
#          [,1]
# [1,] 6.243208
#           [,1]
# [1,] 0.5807969
#          [,1]
# [1,] 0.755684
#           [,1]
# [1,] 0.4613337
#          [,1]
# [1,] 0.199732
#           [,1]
# [1,] 0.1207602
#            [,1]
# [1,] 0.06749014
#            [,1]
# [1,] 0.03587791
#            [,1]
# [1,] 0.01852813
#             [,1]
# [1,] 0.009419275
# ...

# %%
t2 <- t[rowSums(is.na(t))==0, ]

# %%
colnames(t2)
# Out:
#  [1] "ID"                  "Year_Birth"          "Education"
#  [4] "Marital_Status"      "Income"              "Kidhome"
#  [7] "Teenhome"            "Dt_Customer"         "Recency"
# [10] "MntWines"            "MntFruits"           "MntMeatProducts"
# [13] "MntFishProducts"     "MntSweetProducts"    "MntGoldProds"
# [16] "NumDealsPurchases"   "NumWebPurchases"     "NumCatalogPurchases"
# [19] "NumStorePurchases"   "NumWebVisitsMonth"   "AcceptedCmp3"
# [22] "AcceptedCmp4"        "AcceptedCmp5"        "AcceptedCmp1"
# [25] "AcceptedCmp2"        "Complain"            "Z_CostContact"
# [28] "Z_Revenue"           "Response"

# %%
t2[1:200,"NumWebPurchases"]
# Out:
#   [1]  8  1  8  2  5  6  7  4  3  1  2  3  6  1  7  3  4 11  2  4  0  2  6  7  2
#  [26]  5  2  6  3  2  2  4  3  2  5  3  1  7  8  2  0  2  2  3  2  5  4  6  2  4
#  [51]  4  3  5  1  8  3  4  8  7  7  1  1 11  5  2  4 10  9  2  1  7  5  0 10  3
#  [76]  1  3  2  3  1  3  6  5  2  1  3  2  7  2  5  5  2  2  9  6  3  1  4  6  3
# [101]  5  6  7  8  6  6  2  4  9  1  2  6  2  1  1  6  3  3  2  6  5 11  7  5  4
# [126]  1  2  1  2  5  3  5  8  4  3  2  1  4  2  4  8  7  3  8 10  6  0  1  3  1
# [151] 10  3  5  0  2  6  3  3  2  1  2  3  2  2 11  9  2  0  5  4  2  6  1  2  1
# [176]  1  7  4  2  1  8  2  3  5  1  7  4  5  5  8  4 11  7  1  0  1  4  2 11  3

# %%
v <- sapply(t2[1:200,"Marital_Status"],
           function(x){
               if(x=="Single")
                   return("red")
               if(x=="Married")
                   return("blue")
               if(x=="Divorced")
                   return("green")
               if(x=="Together")
                   return("yellow")
               }
               )

# %%
v <- ifelse(t2[1:200,"NumWebPurchases"]>3, "red", "blue")

# %%
plot(Y10[,1],Y10[,2],col=unlist(v))
# Out:
# plot without title

# %%
summary(X[1:200,])
# Out:
#      Income          Recency         MntWines        MntFruits
#  Min.   :  2447   Min.   : 0.00   Min.   :   0.0   Min.   :  0.00
#  1st Qu.: 34460   1st Qu.:21.00   1st Qu.:  17.0   1st Qu.:  1.00
#  Median : 51399   Median :46.50   Median : 135.0   Median :  7.00
#  Mean   : 52218   Mean   :47.31   Mean   : 276.5   Mean   : 24.79
#  3rd Qu.: 68428   3rd Qu.:72.00   3rd Qu.: 470.0   3rd Qu.: 28.25
#  Max.   :157243   Max.   :99.00   Max.   :1349.0   Max.   :194.00
#  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds
#  Min.   :   1.0   Min.   :  0.00   Min.   :  0.00   Min.   :  0.00
#  1st Qu.:  14.0   1st Qu.:  2.00   1st Qu.:  1.00   1st Qu.:  7.00
#  Median :  51.0   Median : 11.00   Median : 10.00   Median : 21.50
#  Mean   : 171.2   Mean   : 36.55   Mean   : 25.80   Mean   : 42.03
#  3rd Qu.: 212.5   3rd Qu.: 44.50   3rd Qu.: 32.25   3rd Qu.: 51.00
#  Max.   :1725.0   Max.   :227.00   Max.   :178.00   Max.   :241.00
# ...

# %%
colnames(t)
# Out:
#  [1] "ID"                  "Year_Birth"          "Education"
#  [4] "Marital_Status"      "Income"              "Kidhome"
#  [7] "Teenhome"            "Dt_Customer"         "Recency"
# [10] "MntWines"            "MntFruits"           "MntMeatProducts"
# [13] "MntFishProducts"     "MntSweetProducts"    "MntGoldProds"
# [16] "NumDealsPurchases"   "NumWebPurchases"     "NumCatalogPurchases"
# [19] "NumStorePurchases"   "NumWebVisitsMonth"   "AcceptedCmp3"
# [22] "AcceptedCmp4"        "AcceptedCmp5"        "AcceptedCmp1"
# [25] "AcceptedCmp2"        "Complain"            "Z_CostContact"
# [28] "Z_Revenue"           "Response"

# %%
X[1:200,][Y10[,1] < -15,]
# Out:
#     Income Recency MntWines MntFruits MntMeatProducts MntFishProducts
# 22    2447 42       1       1         1725            1
# 165 157243 98      20       2         1582            1
#     MntSweetProducts MntGoldProds NumDealsPurchases NumWebPurchases
# 22  1                1            15                0
# 165 2                1            15                0
#     NumCatalogPurchases NumStorePurchases NumWebVisitsMonth
# 22  28                  0                 1
# 165 22                  0                 0

# %%
PCA$ind$coord[1:200,][Y10[,1] < -15,]
# Out:
#     Dim.1    Dim.2    Dim.3     Dim.4     Dim.5
# 22  2.938939 1.595238 0.5278464 -1.992092 9.351078
# 165 4.121620 1.295878 2.2425448 -3.996998 8.862355

# %%
colnames(t)
# Out:
#  [1] "ID"                  "Year_Birth"          "Education"
#  [4] "Marital_Status"      "Income"              "Kidhome"
#  [7] "Teenhome"            "Dt_Customer"         "Recency"
# [10] "MntWines"            "MntFruits"           "MntMeatProducts"
# [13] "MntFishProducts"     "MntSweetProducts"    "MntGoldProds"
# [16] "NumDealsPurchases"   "NumWebPurchases"     "NumCatalogPurchases"
# [19] "NumStorePurchases"   "NumWebVisitsMonth"   "AcceptedCmp3"
# [22] "AcceptedCmp4"        "AcceptedCmp5"        "AcceptedCmp1"
# [25] "AcceptedCmp2"        "Complain"            "Z_CostContact"
# [28] "Z_Revenue"           "Response"

# %% [markdown]
# # Cars93 Tutorial

# %%
library(dbscan)
library(ggplot2)
library(MASS)
library(FactoMineR)
library(repr)
library(scatterplot3d)
library(uwot)
library(kernlab)
library(microbenchmark)
# Out:
# Caricamento pacchetto: ‘dbscan’
#
#
# Il seguente oggetto è mascherato da ‘package:stats’:
#
#     as.dendrogram
#
#
# Caricamento del pacchetto richiesto: Matrix
#
#
# Caricamento pacchetto: ‘kernlab’
#
#
# Il seguente oggetto è mascherato da ‘package:ggplot2’:
#
#     alpha

# %%
options(repr.plot.width=6, repr.plot.height=6)

# %% [markdown]
# Functions for tSNE.

# %%
source("./functions.R")

# %% [markdown]
# Opening the data

# %%
data(Cars93)

# %% [markdown]
# Cars93 contains Data from 93 Cars on Sale in the USA in 1993. Here we have quite many variables, including multiple labels.

# %%
head(Cars93)
# Out:
#   Manufacturer Model   Type    Min.Price Price Max.Price MPG.city MPG.highway
# 1 Acura        Integra Small   12.9      15.9  18.8      25       31
# 2 Acura        Legend  Midsize 29.2      33.9  38.7      18       25
# 3 Audi         90      Compact 25.9      29.1  32.3      20       26
# 4 Audi         100     Midsize 30.8      37.7  44.6      19       26
# 5 BMW          535i    Midsize 23.7      30.0  36.2      22       30
# 6 Buick        Century Midsize 14.2      15.7  17.3      22       31
#   AirBags            DriveTrain ⋯ Passengers Length Wheelbase Width Turn.circle
# 1 None               Front      ⋯ 5          177    102       68    37
# 2 Driver & Passenger Front      ⋯ 5          195    115       71    38
# 3 Driver only        Front      ⋯ 5          180    102       67    37
# 4 Driver & Passenger Front      ⋯ 6          193    106       70    37
# 5 Driver only        Rear       ⋯ 4          186    109       69    39
# 6 Driver only        Front      ⋯ 6          189    105       69    41
#   Rear.seat.room Luggage.room Weight Origin  Make
# 1 26.5           11           2705   non-USA Acura Integra
# 2 30.0           15           3560   non-USA Acura Legend
# 3 28.0           14           3375   non-USA Audi 90
# 4 31.0           17           3405   non-USA Audi 100
# 5 27.0           13           3640   non-USA BMW 535i
# 6 28.0           16           2880   USA     Buick Century

# %%
colnames(Cars93)
# Out:
#  [1] "Manufacturer"       "Model"              "Type"
#  [4] "Min.Price"          "Price"              "Max.Price"
#  [7] "MPG.city"           "MPG.highway"        "AirBags"
# [10] "DriveTrain"         "Cylinders"          "EngineSize"
# [13] "Horsepower"         "RPM"                "Rev.per.mile"
# [16] "Man.trans.avail"    "Fuel.tank.capacity" "Passengers"
# [19] "Length"             "Wheelbase"          "Width"
# [22] "Turn.circle"        "Rear.seat.room"     "Luggage.room"
# [25] "Weight"             "Origin"             "Make"

# %% [markdown]
# Count NAs on rows and columns

# %%
sum(apply(Cars93,1,function(x) any(is.na(x)))) #how many rows with NA
# Out:
# [1] 11

# %%
sum(apply(Cars93,2,function(x) any(is.na(x)))) #how many columns with NA
# Out:
# [1] 2

# %% [markdown]
# Which columns they are

# %%
apply(Cars93,2,function(x) any(is.na(x)))
# Out:
#       Manufacturer              Model               Type          Min.Price
#              FALSE              FALSE              FALSE              FALSE
#              Price          Max.Price           MPG.city        MPG.highway
#              FALSE              FALSE              FALSE              FALSE
#            AirBags         DriveTrain         EngineSize         Horsepower
#              FALSE              FALSE              FALSE              FALSE
#                RPM       Rev.per.mile Fuel.tank.capacity         Passengers
#              FALSE              FALSE              FALSE              FALSE
#             Length          Wheelbase              Width        Turn.circle
#              FALSE              FALSE              FALSE              FALSE
#             Weight             Origin
#              FALSE              FALSE

# %% [markdown]
# Remove some less-interesting or NA columns

# %%
Cars93 <- Cars93[, !colnames(Cars93) %in% c("Make","Man.trans.avail","Cylinders",
                                            "Luggage.room", "Rear.seat.room")]

# %% [markdown]
# Separate features and labels. Make labels as factors

# %%
for(i in c("Origin","Manufacturer","Model", "Type","AirBags","DriveTrain","Passengers"))
    Cars93[,i] <- factor(Cars93[,i])

# %%
X <- Cars93[,!colnames(Cars93) %in% c("Origin","Manufacturer","Model",
                                      "Type","AirBags","DriveTrain","Passengers")]

# %%
labels <- Cars93[c("Origin","Manufacturer","Model",
                 "Type","AirBags","DriveTrain","Passengers")]

# %% [markdown]
# ## Plot two dimensions

# %%
options(repr.plot.width=8, repr.plot.height=8)
ggplot(Cars93, aes(x=Length, y=Weight, color=Passengers)) +
  geom_point(size=6) + 
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# ## Plot three dimensions

# %%
scatterplot3d(Cars93[["Length"]],
              Cars93[["Weight"]],
              Cars93[["MPG.city"]],
              xlab="Length",
              ylab="Weight",
              zlab="MPG.city",
              color = Cars93[["Passengers"]],
              main = "Cars93 dataset",
              lwd=5, pch=19, angle=60)
# Out:
# Plot with title “Cars93 dataset”

# %% [markdown]
# ## Curse of dimensionality

# %% [markdown]
# Calculate distances in all dimensions for Cars93 data and plot the histogram

# %%
Distance <-  as.vector(as.matrix( dist(X[,1]) ))
L <- length(Distance)
Dimension <- rep(1, L)
Ndim <- dim(X)[2]
for(n in 2:Ndim){
    Distance <- c(Distance, as.vector(as.matrix( dist(X[,1:n]) )))
    Dimension <- c(Dimension, rep(n, L))
    }

# %%
D <- as.data.frame(log(Distance))
colnames(D) <- c("log_distance")
D["dimension"] <- factor(Dimension)

# %%
ggplot(D, aes(x=log_distance, color=dimension)) +
  geom_histogram(fill="white") + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# “Removed 1427 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %% [markdown]
# ## Parametric projections

# %% [markdown]
# ### PCA
#
# The function PCA is part of the package `FactomineR`

# %%
PCA = FactoMineR::PCA(X, ncp = 2)

# %%
Y_PCA = as.data.frame(PCA$ind$coord)

# %%
Y_PCA <- cbind(Y_PCA,labels)

# %% [markdown]
# We can already see some type between car Types. Large cars and Vans are together, meaning they share many features in the data.

# %%
ggplot(Y_PCA, aes(x=Dim.1, y=Dim.2, color=Type)) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# Also some separation between origins. Probably because USA has produced larger and heavier cars than European brands.

# %%
ggplot(Y_PCA, aes(x=Dim.1, y=Dim.2, color=Origin)) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %%
ggplot(Y_PCA, aes(x=Dim.1, y=Dim.2, color=Manufacturer)) +
  geom_point(size=5) + geom_text(aes(label=Manufacturer), color="black") + 
  theme_classic(base_size = 15) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# ### Kernel PCA
#
# is contained in the package `kernlab`. Try out other kernel types beyond the gaussian one. Type `help(kpca)` to see how to use the options. Remember to standardize the data first. other packages do that internally.

# %%
X_std = apply(X, 2, function(x){(x-mean(x))/sd(x)})

# %%
Y_kpca = kernlab::kpca(as.matrix(X_std), 
     features = 2,
     kernel = "rbfdot", 
     kpar = list(sigma = .3),
     th = 1e-4, 
     na.action = na.omit)

# %%
Y_kpca = as.data.frame(Y_kpca@pcv)

# %%
Y_kpca <- cbind(Y_kpca,labels)

# %%
colnames(Y_kpca)[1:2] <- c("Dim.1","Dim.2")

# %% [markdown]
# It is clear how some midsize cars are close to Vans and Large cars, while small and compact vehicles are far apart

# %%
ggplot(Y_kpca, aes(x=Dim.1, y=Dim.2, color=Type)) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# ### Linear Discriminant Analysis
#
# contained in the `MASS` package. The functions run a regression based on the projection,so we provide prior probabilities for each class (they give weight to each class). `formula = Type ~ Price+MPG.city+MPG.highway+Length+Wheelbase+Width+Turn.circle+Weight` means that those numeric variables are part of the regression (projection) against the Type. Note we do not use all variables (some are probably collinear, like the price and the maximum price).

# %%
Y_lda <- lda(formula = Type ~ Price+MPG.city+MPG.highway+Length+Wheelbase+Width+Turn.circle+Weight, 
          data = Cars93)

# %%
Y_lda$scaling
# Out:
#             LD1          LD2          LD3           LD4          LD5
# Price        0.031687753 -0.082254431 -0.0555412205  0.015259090 -9.884964e-02
# MPG.city    -0.036110567  0.236708761  0.2002795680  0.163456010 -4.327626e-01
# MPG.highway  0.104796674 -0.251643398 -0.1075862234 -0.040448574  3.455385e-01
# Length       0.031411081 -0.141962430  0.0357482583  0.013378046 -1.380905e-02
# Wheelbase   -0.271549462  0.036779540  0.2356106172  0.054475656  3.253685e-02
# Width        0.032440136  0.311217686 -0.3743068768  0.587346230 -1.081074e-01
# Turn.circle -0.095468997 -0.061511488 -0.1422626136 -0.142939796  1.272769e-01
# Weight      -0.001519967  0.001654449  0.0005126602 -0.002764801 -9.370395e-05

# %% [markdown]
# The scaling factors tell you that on the first component of the projection you have the two regression printed with the code below and so on for the other LD components

# %%
Ndim <- dim(Y_lda$scaling)[1]
LD <- as.character(Y_lda$scaling[,"LD1"])
FEATURE <- rownames(Y_lda$scaling)
cat("Regression for LD1 = ")
for(i in 1:Ndim-1) cat(LD[i],"*",FEATURE[i], "+", sep="") 
cat(LD[Ndim],"*",FEATURE[Ndim], "\n\n", sep="")
LD <- as.character(Y_lda$scaling[,"LD2"])
FEATURE <- rownames(Y_lda$scaling)
cat("Regression for LD2 = ")
for(i in 1:Ndim-1) cat(LD[i],"*",FEATURE[i], "+", sep="") 
cat(LD[Ndim],"*",FEATURE[Ndim], sep="")
# Out:
# Regression for LD1 = *+0.0316877530074564*Price+-0.0361105674980681*MPG.city+0.104796674150593*MPG.highway+0.0314110805471599*Length+-0.271549462191567*Wheelbase+0.0324401359458192*Width+-0.0954689965469444*Turn.circle+-0.00151996673404783*Weight
#
# Regression for LD2 = *+-0.0822544310054372*Price+0.236708760742852*MPG.city+-0.251643397560538*MPG.highway+-0.141962429650229*Length+0.0367795401609462*Wheelbase+0.31121768628625*Width+-0.0615114875289651*Turn.circle+0.00165444949752201*Weight

# %% [markdown]
# We calculate those features using some good old vectorization in R. First take the coefficients, Then multiply by the data and do the sum by rows.

# %%
paste("LD",n,sep="")
# Out:
# [1] "LD6"

# %%
LD <- list()
Ndim <- dim(Y_lda$scaling)[2]
for(n in 1:Ndim){
    coeff_LD <- matrix(rep(Y_lda$scaling[,paste("LD",n,sep="")],dim(X)[1]),
       nrow=dim(X)[1], byrow=T)
    LD[[n]] <- rowSums(X * coeff_LD)
}

# %% [markdown]
# make a proper dataframe and plot

# %%
Y_LDAplot <- data.frame( matrix(unlist(LD),
                    nrow=dim(X)[1],
                    byrow=F) )
colnames(Y_LDAplot) <- sapply( 1:Ndim, function(n) paste("LD",n,sep="") )

# %%
Y_LDAplot <- cbind(Y_LDAplot,labels)

# %% [markdown]
# Again some separation between types (used as labels to improve the projection)

# %%
ggplot(Y_LDAplot, aes(x=LD1, y=LD2, color=Type)) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# ## Non-parametric methods

# %% [markdown]
# ### tSNE
#
# From the code in the book or your own improved code.

# %% [markdown]
# Run your personal tSNE function (in my case `sam_tsne`) or the one from the book (`casl_tsne`). Here `init`, `momentum` and `early_ex` are not options found in `casl_tsne`

# %%
Y_tsne <- sam_tsne(X_std, init = FALSE,
                    momentum=list(init=.7, final=.9, iter=200L),
                    early_ex=list(factor=12, iter=500L), 
                    perplexity = 5, rho=100)

# %%
Y_tsne = as.data.frame(Y_tsne)

# %%
colnames(Y_tsne) <- c("tSNE1", "tSNE2")

# %%
Y_tsne <- cbind(Y_tsne,labels)

# %%
summary(Y_tsne)
# Out:
#      tSNE1             tSNE2              Origin      Manufacturer     Model
#  Min.   :-21.123   Min.   :-14.6338   USA    :48   Chevrolet: 8    100    : 1
#  1st Qu.: -9.760   1st Qu.: -7.0781   non-USA:45   Ford     : 8    190E   : 1
#  Median :  2.161   Median : -0.3306                Dodge    : 6    240    : 1
#  Mean   :  0.000   Mean   :  0.0000                Mazda    : 5    300E   : 1
#  3rd Qu.:  8.978   3rd Qu.:  6.7324                Pontiac  : 5    323    : 1
#  Max.   : 18.726   Max.   : 15.5487                Buick    : 4    535i   : 1
#                                                    (Other)  :57    (Other):87
#       Type                  AirBags   DriveTrain Passengers
#  Compact:16   Driver & Passenger:16   4WD  :10   2: 2
#  Large  :11   Driver only       :43   Front:67   4:23
#  Midsize:22   None              :34   Rear :16   5:41
#  Small  :21                                      6:18
#  Sporty :14                                      7: 8
#  Van    : 9                                      8: 1

# %%
ggplot(Y_tsne, aes(x=tSNE1, y=tSNE2, color=Type)) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# #### Benchmarking the tSNEs
#
# Benchmarking improved tSNE VS tSNE from the book CASL and showing execution time (in seconds)

# %%
MB <- microbenchmark("Improved" = { sam_tsne(X_std, init = PCA$ind$coord,
                                    momentum=list(init=.5, final=.9, iter=200L),
                                    early_ex=list(factor=12, iter=200L), 
                                    perplexity = 10, rho=100) },
                     "CASL" =  { casl_tsne(X_std, init = PCA$ind$coord,
                                    perplexity = 20, rho=100) },
                      times=1 )

# %%
MB['time (s)'] = MB['time']/1e9

# %%
MB
# Out:
#   expr     time        time (s)
# 1 CASL     40502936855 40.502937
# 2 Improved  4033832246  4.033832

# %% [markdown]
# ### UMAP
#
# part of the package `uwot`

# %%
Y_umap <- uwot::umap(X_std, n_neighbors = 10, learning_rate = 0.5, init = "random")

# %%
Y_umap = as.data.frame(Y_umap)

# %%
colnames(Y_umap) <- c("UMAP1", "UMAP2")

# %%
Y_umap <- cbind(Y_umap,labels)

# %%
summary(Y_umap)
# Out:
#      UMAP1             UMAP2             Origin      Manufacturer     Model
#  Min.   :-3.7963   Min.   :-1.9449   USA    :48   Chevrolet: 8    100    : 1
#  1st Qu.:-2.7822   1st Qu.:-0.9373   non-USA:45   Ford     : 8    190E   : 1
#  Median :-0.9329   Median :-0.4748                Dodge    : 6    240    : 1
#  Mean   : 0.0000   Mean   : 0.0000                Mazda    : 5    300E   : 1
#  3rd Qu.: 1.5889   3rd Qu.: 1.2371                Pontiac  : 5    323    : 1
#  Max.   : 5.5466   Max.   : 2.9968                Buick    : 4    535i   : 1
#                                                   (Other)  :57    (Other):87
#       Type                  AirBags   DriveTrain Passengers
#  Compact:16   Driver & Passenger:16   4WD  :10   2: 2
#  Large  :11   Driver only       :43   Front:67   4:23
#  Midsize:22   None              :34   Rear :16   5:41
#  Small  :21                                      6:18
#  Sporty :14                                      7: 8
#  Van    : 9                                      8: 1

# %% [markdown]
# Very nice pattern

# %%
ggplot(Y_umap, aes(x=UMAP1, y=UMAP2, color=Type )) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %%
ggplot(Y_umap, aes(x=UMAP1, y=UMAP2, color=Manufacturer )) +
  geom_point(size=5) + 
  theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# Almost all compact cars are from USA and in their own separate group. They have probably unusual characteristics compared to the others.

# %%
ggplot(Y_umap, aes(x=UMAP1, y=UMAP2, color=Origin )) +
  geom_point(size=5) + geom_text(aes(label=Type), color="black") +
  theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# ## k-means clustering
#
# k-means clustering of the umap projection to see some patterns or outliers

# %%
res <- stats::kmeans(x=Y_umap[,c("UMAP1","UMAP2")],
              centers=5)

# %%
Y_kmeans <- cbind(factor(res$cluster), Y_umap, X)

# %%
names(Y_kmeans)[1] <- "Clusters"

# %%
head(Y_kmeans)
# Out:
#   Clusters UMAP1      UMAP2      Origin  Manufacturer Model   Type
# 1 2         4.3647692 -0.4180626 non-USA Acura        Integra Small
# 2 3        -2.7721604 -0.4341374 non-USA Acura        Legend  Midsize
# 3 3        -1.6463885 -0.3798824 non-USA Audi         90      Compact
# 4 3        -2.7822215 -0.5338195 non-USA Audi         100     Midsize
# 5 3        -2.4441923 -0.4553568 non-USA BMW          535i    Midsize
# 6 5         0.4226041 -1.0469681 USA     Buick        Century Midsize
#   AirBags            DriveTrain Passengers ⋯ EngineSize Horsepower RPM
# 1 None               Front      5          ⋯ 1.8        140        6300
# 2 Driver & Passenger Front      5          ⋯ 3.2        200        5500
# 3 Driver only        Front      5          ⋯ 2.8        172        5500
# 4 Driver & Passenger Front      6          ⋯ 2.8        172        5500
# 5 Driver only        Rear       4          ⋯ 3.5        208        5700
# 6 Driver only        Front      6          ⋯ 2.2        110        5200
#   Rev.per.mile Fuel.tank.capacity Length Wheelbase Width Turn.circle Weight
# 1 2890         13.2               177    102       68    37          2705
# 2 2335         18.0               195    115       71    38          3560
# 3 2280         16.9               180    102       67    37          3375
# 4 2535         21.1               193    106       70    37          3405
# 5 2545         21.1               186    109       69    39          3640
# 6 2565         16.4               189    105       69    41          2880

# %%
ggplot(Y_kmeans, aes(x=UMAP1, y=UMAP2, color=Clusters, )) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %%
ggplot(Y_kmeans, aes(x=UMAP1, y=UMAP2, color=Type, )) +
  geom_point(size=5) + theme_classic(base_size = 20) +
  theme(legend.position="top")
# Out:
# plot without title

# %% [markdown]
# Let's see average length and weight in the various clusters. Small cars are lighter (2300 pounds) and compact cars are quite heavier, though lighter than all the other sizes.

# %%
A <- aggregate(. ~ Clusters, Y_kmeans[c("Weight","Clusters")], mean)
print(A)
# Out:
#   Clusters   Weight
# 1        1 3670.227
# 2        2 2300.682
# 3        3 3261.176
# 4        4 3697.222
# 5        5 2856.739

# %%
plot(Y_kmeans[c("Weight","Clusters")])
# Out:
# plot without title
